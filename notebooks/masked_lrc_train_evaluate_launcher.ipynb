# %% [markdown]
# ##**Paper "No clues, good clues: Out of context Lexical Relation Classification"**
# ####Experiment reproducibility for Lexical Relation Classification: Templates TM1-TM3

# %%
# !nvidia-smi

# %% [markdown]
# **Download datasets and scripts**

# %%
# !curl -L -O 'https://raw.github.com/sid-unizar/LRC/main/datasets/datasets.zip'
# !unzip -o datasets.zip
# !curl -L -O 'https://raw.github.com/sid-unizar/LRC/main/scripts/scripts.zip'
# !unzip -o scripts.zip

# %%
# to mount google drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# THESE ARE THE PACKAGES USED IN THE EXPERIMENTS
# UNCOMMENT THE FOLLOWING LINES, IF YOU DO NOT WANT TO USE THE LAST VERSIONS
# OF THE TRANSFORMERS AND DATASETS PACKAGES

# !pip install 'transformers==4.25.1' --force-reinstall
# !pip install 'datasets==2.8.0' --force-reinstall

# %%
# !pip install transformers
# !pip install datasets
# !pip install accelerate

# %%
#########
# Parameter --model, one of:
#    "roberta-large"
#    "roberta-base"
#    "bert-large-uncased-whole-word-masking"
#    "bert-base-uncased"
#
# Parameter --train_templates:
#   template TM1:,
#          "' <W1> ' <MASK> ' <W2> '"
#   template TM2:
#          " <W1> <MASK> <W2> "
#   template TM3:
#          "Today, I finally discovered the relation between <W1> and <W2>: <W1> is the <MASK> of <W2>."
#
# Modify the rute to the folder containing the `masked_lrc_train_evaluate.py` script
# and the folder containing the datasets

# !python /content/LRC-0C0F/scripts/masked_lrc_train_evaluate.py \
	--train_templates "' <W1> ' <MASK> ' <W2> '"   \
	--model  "roberta-base" \
	--nepochs 10 \
	--dir_output_results "/content/res/" \
	--batch_size 32 \
	--warm_up 0.1 \
	--nrepetitions 1 \
	--dataset "EVALution" \
	--date `date "+%D-%H:%M:%S"` \
	--train_file "/content/LRC-0C0F/datasets/EVALution/train.tsv" \
	--test_file "/content/LRC-0C0F/datasets/EVALution/test.tsv" \
	--val_file "/content/LRC-0C0F/datasets/EVALution/val.tsv" # comment this line, if there is no val dataset (i.e. CogALexV)
